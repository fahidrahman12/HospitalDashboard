# %%
import pandas as pd
import os
print(os.getcwd())
# Out:
# C:\Users\fahed\PycharmProjects\HospitalDashboard\src

# %%
data= pd.read_csv(r'C:\Users\fahed\PycharmProjects\HospitalDashboard\data\Hospital.csv')

# %%
print(data.describe())
# Out:
#        OrganisationID     Latitude    Longitude
# count    1.211000e+03  1209.000000  1209.000000
# mean     1.375611e+06    52.317509    -1.293855
# std      3.024986e+06     1.213026     1.294781
# min      1.797000e+04    49.913063    -6.309277
# 25%      4.064900e+04    51.410404    -2.154729
# 50%      4.311000e+04    52.038059    -1.369305
# 75%      7.610700e+04    53.378357    -0.217204
# max      1.095615e+07    55.773289     1.730521

# %%
print(data.shape)
# Out:
# (1211, 22)

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1211 entries, 0 to 1210
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   OrganisationID      1211 non-null   int64
#  1   OrganisationCode    1211 non-null   object
#  2   OrganisationType    1211 non-null   object
#  3   SubType             1211 non-null   object
#  4   Sector              1211 non-null   object
#  5   OrganisationStatus  1211 non-null   object
#  6   IsPimsManaged       1211 non-null   bool
#  7   OrganisationName    1211 non-null   object
#  8   Address1            883 non-null    object
#  9   Address2            727 non-null    object
#  10  Address3            147 non-null    object
#  11  City                1196 non-null   object
#  12  County              973 non-null    object
#  13  Postcode            1210 non-null   object
#  14  Latitude            1209 non-null   float64
# ...

# %%
df= data[['OrganisationID', 'Latitude', 'Longitude', 'City', 'County', 'Postcode', 'ParentName'] ]
df.head()
# Out:
#    OrganisationID   Latitude  Longitude              City              County  \
# 0           17970  51.379997  -0.406042  Walton-on-Thames              Surrey
# 1           17981  51.315132  -0.556289            Woking              Surrey
# 2           18102  51.437195  -2.847193          Clevedon                Avon
# 3           18138  53.459743  -2.245469        Manchester  Greater Manchester
# 4           18142  52.078121  -0.030604           Royston                 NaN
#
#    Postcode                                         ParentName
# 0  KT12 3LD                           Virgin Care Services Ltd
# 1  GU22 7HS                           Virgin Care Services Ltd
# 2  BS21 6BS  North Somerset Community Partnership Community...
# 3   M15 5AT              Bridgewater Hospital (Manchester) Ltd
# 4   SG8 5JP                           Partnerships In Care Ltd

# %% [markdown]
# Look at the nulls

# %%
df.info(verbose= True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1211 entries, 0 to 1210
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrganisationID  1211 non-null   int64
#  1   Latitude        1211 non-null   float64
#  2   Longitude       1211 non-null   float64
#  3   City            1196 non-null   object
#  4   County          973 non-null    object
#  5   Postcode        1210 non-null   object
#  6   ParentName      1211 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 75.7+ KB

# %%
data[data['County'].isnull() ].head()
# Out:
#     OrganisationID OrganisationCode OrganisationType   SubType  \
# 4            18142            NMV01         Hospital  Hospital
# 11           18317            NR527         Hospital  Hospital
# 14           18353            NT205         Hospital  Hospital
# 19           18359            NT212         Hospital  Hospital
# 24           18365            NT218         Hospital  Hospital
#
#                 Sector OrganisationStatus  IsPimsManaged  \
# 4   Independent Sector            Visible           True
# 11  Independent Sector            Visible           True
# 14  Independent Sector            Visible           True
# 19  Independent Sector            Visible           True
# 24  Independent Sector            Visible           True
#
#                             OrganisationName        Address1  \
# 4                           Kneesworth House  Old North Road
# 11                      Mount Gould Hospital             NaN
# ...

# %%
data.loc[data['OrganisationID'] == 9970086, 'Latitude'] = 51.255273
data.loc[data['OrganisationID'] == 9970086, 'Longitude'] = 0.641930
data.loc[data['OrganisationID'] == 10617567, 'Latitude'] = 49.18804
data.loc[data['OrganisationID'] == 10617567, 'Longitude'] = -2.10491

# %%
print(list(data.columns))
# Out:
# ['OrganisationID', 'OrganisationCode', 'OrganisationType', 'SubType', 'Sector', 'OrganisationStatus', 'IsPimsManaged', 'OrganisationName', 'Address1', 'Address2', 'Address3', 'City', 'County', 'Postcode', 'Latitude', 'Longitude', 'ParentODSCode', 'ParentName', 'Phone', 'Email', 'Website', 'Fax,,,']

# %% [markdown]
# ## lets filter for only column swe'll need

# %%
data_cleaned= data[['OrganisationID','OrganisationName', 'Latitude', 'Longitude', 'City', 'County', 'Postcode','Address1', 'ParentName','OrganisationType','Sector']]

# %%
data_cleaned.head()
# Out:
#    OrganisationID                                   OrganisationName  \
# 0           17970  Walton Community Hospital - Virgin Care Servic...
# 1           17981            Woking Community Hospital (Virgin Care)
# 2           18102                  North Somerset Community Hospital
# 3           18138                               Bridgewater Hospital
# 4           18142                                   Kneesworth House
#
#     Latitude  Longitude              City              County  Postcode  \
# 0  51.379997  -0.406042  Walton-on-Thames              Surrey  KT12 3LD
# 1  51.315132  -0.556289            Woking              Surrey  GU22 7HS
# 2  51.437195  -2.847193          Clevedon                Avon  BS21 6BS
# 3  53.459743  -2.245469        Manchester  Greater Manchester   M15 5AT
# 4  52.078121  -0.030604           Royston                 NaN   SG8 5JP
#
#                             Address1  \
# 0                                NaN
# 1                                NaN
# ...

# %%
import os
print(os.getcwd())#data_cleaned.to_csv(, index=False)
# Out:
# C:\Users\fahed\PycharmProjects\HospitalDashboard

# %%
data_cleaned.to_csv('data_cleaned_2')
